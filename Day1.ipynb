# %%
test = """L68
L30
R48
L5
R60
L55
L1
L99
R14
L82"""

# %%
actual = """L49
L24
R48
L16
L2
R8
R48
L27
L2
L47
R48
L41
L3
R39
R45
R43
L4
R47
R38
R17
R45
L4
L25
L30
R7
L44
R15
R42
L40
R11
R35
R36
R4
L24
R40
L11
R9
R48
R3
R37
L30
L2
R45
R24
L26
L40
L11
R46
L27
R51
L30
L90
R20
R4
R85
L96
R7
R1
L53
R82
R70
L61
R70
L60
L54
L81
R86
R82
R18
R54
L26
R58
L69
L17
L99
L58
R10
R83
R64
R79
L5
L27
L34
R87
L12
L89
R19
R70
L40
R42
R10
R37
R79
R74
L53
L74
R27
L90
R69
L69
R42
R8
R450
L49
R80
R69
R2
L34
L68
L74
R87
L213
R15
R85
R593
L93
R32
L32
L7
R34
L31
R93
L56
L37
L10
L25
L47
R886
R62
L62
L20
L687
L37
L56
L41
R41
R48
L56
R8
R29
L30
L99
L61
R90
R12
L41
R14
R21
L61
R256
R39
L69
L324
R24
L49
L51
R20
L65
R925
R17
R44
L41
L73
L78
R25
R69
L543
L78
R17
L91
L86
L62
R783
R95
L40
L38
R405
L75
L30
R99
L32
R33
L8
L64
L41
L32
L3
L12
R36
R66
R58
R108
L75
R2
L34
L35
R88
L64
L44
R34
L8
L35
R63
R29
R33
R78
R243
R94
L56
L34
R81
L55
L13
L35
R42
L50
R33
R59
R397
L73
R27
L697
L3
R58
R415
R44
R69
R14
R70
R18
L88
L84
L11
L78
L227
R97
L97
R97
L27
R30
R22
R29
R49
R36
L236
L51
L49
L594
L6
R76
R18
L4
R36
R874
L301
L33
R539
R29
R20
L48
R378
R77
R22
R403
R11
R35
R68
R896
L40
R220
R24
R91
R51
R311
R47
R35
L65
R266
R99
L17
L18
R52
R25
L18
R82
L2
L85
R27
R95
L76
R90
L90
R117
L56
L527
R527
L98
R11
R29
R98
L34
L67
L66
R66
L63
L9
L81
L9
L838
R24
R76
R12
L19
R7
L551
R51
L85
L73
R58
R956
L578
L78
R9
L46
L305
L58
L42
R442
R76
R30
R8
R86
R31
R69
L12
L88
R595
R5
L742
R3
L61
R195
R19
L138
L22
R93
L923
R92
L35
R44
R86
R89
L38
R8
R330
R81
L981
L71
R535
L84
R58
L89
R66
R22
L37
L4
R4
L35
R38
R97
R17
L55
L897
L58
R25
L211
L21
R43
R57
L96
L4
R87
L97
L10
L80
L53
R53
L679
R31
R648
R46
R376
L422
R955
R92
R14
R69
L357
R14
R699
L2
R16
L63
L137
L89
R64
R25
L50
L81
R66
L96
L365
R8
L82
L2
L80
R14
L889
R57
R43
L88
L4
R49
R556
R53
R31
R660
R61
L738
L23
R91
R9
R38
L84
L365
L49
L68
L20
L94
R12
R72
R77
R690
L707
L32
R63
L33
L87
R422
R182
R83
R79
R48
L27
L96
L88
R27
R63
R15
L17
L4
L46
R81
R640
L85
R51
L83
R42
R430
L61
L27
R3
R55
L317
L83
L180
R63
R76
L71
R12
R90
R810
R39
R62
R70
L9
L62
L92
L26
L11
L173
R72
R878
R41
R211
R21
R78
L99
R167
L167
L19
R77
L54
L67
L37
L50
R883
R721
R946
L89
L18
L24
R250
R285
L24
R20
L30
L346
L24
L22
L30
R96
R3
L47
R48
L20
R37
L29
L36
L55
L62
R37
L20
L17
L83
R99
R37
R90
L51
L91
R442
L824
R55
L44
L381
L30
L2
R55
L55
L4
R904
R71
R78
R58
L92
R902
L17
L778
L71
R49
L5
R205
L1
R53
R48
R939
R61
R51
L51
R95
L95
R11
L11
L63
R85
L22
R51
L751
L4
R233
L29
R90
R32
L590
R5
R63
R60
R24
L842
R40
L382
L3
L97
R874
L3
L280
L3
L787
L1
L58
R58
R846
R94
R60
R3
L10
R7
L61
L39
L47
L53
L48
L152
L20
R584
R77
L1
R60
R33
R29
L62
R78
L92
L86
L94
R94
R6
R75
R19
R62
L39
L23
L68
L66
L85
R27
L32
L976
L963
R49
R12
R2
L11
L573
L45
R22
L93
R19
R56
R54
R79
L325
R15
L8
L275
R85
L119
R19
R65
L65
L90
R53
L622
L41
R65
L65
R34
L861
L1
R28
R20
R419
L48
L545
R27
L73
R42
R3
L45
L271
L29
R636
R564
L564
L36
R21
R79
L27
L287
L86
R62
L62
R73
R90
L63
R94
R85
R30
L26
L533
L605
L45
L82
L18
R954
L54
L841
L52
L7
L64
L96
R60
L34
L132
L64
R30
R6
L6
R13
R29
L50
L5
R98
L685
R519
L33
R904
R58
L948
R46
R33
L774
R395
L37
L36
R40
L48
L71
R52
L68
L48
L84
L9
R9
R27
L27
L62
L883
L55
R133
L992
L436
R31
L37
L46
R26
R708
R13
R62
L75
L548
L8
L7
R61
R37
L674
R52
L8
R108
L274
L2
R74
L25
R441
R86
R17
R176
L193
L28
L66
L94
L8
R392
L96
R764
L88
R461
R76
L67
R81
R73
L12
L93
L10
L96
L12
R923
L79
R41
L533
R14
L86
L78
L80
L94
R95
R43
R970
R411
L24
R61
L61
R43
L34
L68
L606
R65
R46
R854
R716
L94
R806
R799
L792
R10
L45
R3
L94
L93
L58
R90
R20
R32
L54
R54
L7
L90
R97
L4
R34
L30
R7
L34
L73
L545
R50
L41
R62
L6
R702
R478
L495
L93
L15
R3
R79
R827
L72
L35
R57
L77
L846
R334
R77
L25
L19
R30
R70
L27
L72
L1
L69
R69
R86
R35
L92
R90
R81
R918
L64
L54
L64
R79
L709
R25
L23
L91
R56
L56
R855
R79
L151
L81
R19
R76
R86
L13
L87
R782
R68
L38
L24
L29
R287
R26
R28
R27
L55
L506
R34
R94
R106
L90
L46
L84
L80
R246
L346
L77
R77
L25
R556
R69
L89
R89
L26
L74
R62
R38
L99
L21
L15
R435
R31
R97
L28
R10
R90
L97
L3
L5
L77
L65
R29
R29
L11
L5
L2
R74
R33
L42
R54
L28
R616
R50
L27
R27
L27
L49
L72
R92
R6
L33
R93
R58
L26
L71
L21
R86
L44
L75
L67
R28
L62
R63
L96
R135
L65
R41
L44
R27
L27
R30
L955
L63
R94
L493
L22
R56
L36
L11
L60
R897
L201
L1
R33
R61
L14
R36
R17
R47
L347
R332
R35
R34
L10
L59
L447
L15
L4
L34
L8
L26
R84
L17
L33
R31
L44
R13
R91
L91
R61
L25
R64
R43
R57
L71
R71
L85
R485
L825
L71
L699
L405
L98
R198
R84
R3
R13
L39
R44
L979
R621
L47
L77
R68
R37
L22
L6
L428
L472
R28
R2
L670
R45
R195
R55
R88
R66
L81
R604
R68
L261
R78
R56
L96
R23
R24
R76
L18
R18
L83
R83
R61
L61
L68
R4
R135
R85
R11
R333
L884
R21
L70
L67
L10
L90
R40
L44
R804
L53
R48
R62
L74
L38
R84
R24
L72
R59
L61
R21
R19
R72
L91
R78
L40
L2
R67
L414
R11
R46
R54
R40
L410
R99
R73
R56
R94
R17
L95
R726
R62
R38
L7
L91
R69
R329
R549
L21
R75
R91
L94
R2
R198
L390
L10
R99
R1
L790
L81
R98
R73
L837
L948
R38
R86
R79
L18
R62
L62
L109
R54
L40
L75
L3
L727
R96
L66
L67
R16
R75
L73
L88
R7
L6
R6
L6
R47
L94
L976
R543
L39
L75
R20
L788
R68
L69
R55
R84
L70
L57
R721
L85
R21
R91
R9
R4
L48
R44
R63
L848
R385
L26
L74
R71
L6
L565
L702
L98
L23
L77
L62
L38
L53
L547
R26
R43
L917
L67
L67
R974
R893
L85
L67
R2
R346
L184
L127
R830
L84
R884
L33
L67
R54
L13
L33
L98
L104
R11
L17
R60
L460
L66
R17
L51
L81
L19
L13
R3
L90
R328
L87
L41
R57
R18
R67
R17
R15
R26
L8
L392
L97
L70
L644
L629
R7
R88
R140
R28
L23
L492
L8
L94
L14
L399
L2
R9
L76
R22
R52
R602
L56
L44
R79
L164
L15
L22
R72
R805
L85
R64
L73
R89
R750
L87
R55
L65
R349
R50
L2
R982
R34
L16
R74
R74
L122
L83
R57
R35
R65
R351
R22
R90
L50
R23
R66
R97
L45
R34
R49
R985
R434
R62
R118
R64
L13
L68
L14
R35
R960
R57
L57
R12
L951
R346
R29
L36
L63
L60
L77
R71
L19
R48
L36
L64
L934
R23
L59
R70
R127
R11
L32
R28
L34
R90
R10
L58
L65
R47
R18
R58
R306
L67
R976
R85
R119
R10
R39
R87
L36
L19
R51
R18
R31
R72
R88
L360
R4
L875
R755
R716
L76
L1
R77
R20
R80
L243
R27
R16
R698
L646
R48
L64
R2
R462
L36
R1
R81
R61
L68
R30
L769
R18
L41
L77
L10
L756
L53
R19
L12
L89
R1
R97
R14
L8
R97
R86
L53
R67
R17
R78
L376
R29
R45
R29
L98
L38
L13
L73
R845
R80
R485
R982
L29
L78
R83
L593
L3
L972
R539
R61
L67
R58
R9
L40
L14
L66
L80
R43
R94
L537
R19
L31
R58
L27
L9
L310
L99
L1
L54
L46
L925
R191
R34
R79
R80
R41
L313
L60
L49
L26
R22
L74
L81
L6
R76
R27
R44
R570
R570
L7
L48
L95
L50
L65
L93
R6
R52
L45
L19
L36
R44
L44
R795
L95
L51
R51
L999
L1
L20
L75
L1
L4
L90
L10
L40
R88
R106
L35
R81
R6
R38
R67
L11
R55
R394
R51
L47
L56
R89
R66
R74
R79
R95
R96
L34
R38
R74
L93
R45
R22
R52
R58
L58
L38
L623
R61
R74
L32
L45
R703
R30
R90
R98
L72
R40
R55
R59
L54
R26
L70
R798
R88
R15
R32
R86
R79
R1
R87
L93
R5
L828
R28
L502
R2
R25
L25
L83
L85
L32
R53
R14
L15
R16
L68
L407
L88
R37
L42
R322
R39
L29
L873
R43
L54
R72
R77
R3
L38
L92
L133
R63
R67
L55
L12
L412
L70
R82
R27
R86
R17
R70
L47
L75
L41
L59
L178
L906
L94
L15
L285
L31
R131
R63
R75
L304
L18
R857
R27
R193
L93
L86
R91
R95
R11
L79
R21
R27
R53
L34
R501
R47
R919
R34
R90
R42
R14
R54
R47
L47
R10
L10
L43
L57
L38
L49
R87
L68
R46
L78
L17
L41
L34
R66
L74
L11
L89
L222
R22
L66
R19
L12
L741
R27
R32
L504
L834
L71
R16
R69
L35
L591
L9
R68
L791
L24
R31
L4
R17
R514
L15
R4
L66
L34
R34
R77
L80
R69
R68
L68
L513
L21
L166
L5
R72
L85
L382
R69
R85
R546
L98
R98
L34
L966
L43
R43
R15
R85
R83
L80
L1
L18
L12
L58
L94
R80
R921
R76
L97
R8
R70
L30
L48
R81
R71
L70
L94
R12
L71
L229
R556
R44
R55
L61
R37
R48
R508
L311
R62
R62
R43
L5
L57
R84
L165
R90
L90
R27
L36
R35
R29
L55
R80
L80
L30
R30
R96
R4
R94
R63
R743
R14
L14
R96
R204
L883
R854
R30
L90
R80
L996
R69
R36
L46
L16
L38
R24
R55
L79
R69
L57
R655
L99
L9
R38
L97
L40
R740
L23
L126
L68
R17
L87
R41
L23
L190
R13
L248
L6
R93
L71
L22
L71
R91
L20
L25
L27
R68
R84
L266
L353
L76
L5
R32
R82
R538
L552
R65
L344
R26
L47
L9
R22
L13
R48
R71
R66
R15
R34
R81
L171
L2
R698
R3
R57
L64
R627
L563
L8
R8
L90
R366
L741
L417
L18
L87
L93
R180
R606
R50
L56
R33
R43
R38
L77
R763
L97
R67
R90
L31
R80
L709
L4
R4
R29
L29
L603
L772
L20
R84
L89
L60
R60
L69
L31
R18
L89
R76
R286
R89
R24
R14
L18
R65
L25
L40
L74
R74
L51
R51
R93
L94
R80
L79
L76
L24
L35
L72
L93
R26
L14
R388
R90
R64
L64
R37
L6
R79
R46
L95
R449
R99
L402
R45
L68
L74
R37
R74
L58
L995
R68
L26
L75
R499
L58
R8
R13
L11
R24
L41
R44
L72
R69
R84
R16
R88
R93
L781
R38
L98
R841
L14
R33
L51
R51
R28
L228
L91
L77
L232
R203
R31
R66
L73
R73
R76
L44
R68
L984
L16
L68
R14
L683
R137
R18
R65
R944
L66
R789
R3
L253
L48
L13
L39
L98
R99
L21
L27
L8
R26
R29
L69
R44
L75
L95
R95
L64
L36
R5
R95
L96
L63
R10
L293
L58
R47
L40
R34
R217
L58
R63
L77
L96
L90
L25
R625
R548
L86
R38
R92
R8
R82
R18
L39
R255
L4
L12
R36
R44
L701
L25
R46
R507
R767
L74
R87
R61
L552
R63
L7
L11
R73
L9
L5
R741
L41
L92
L47
L61
L47
L676
L77
L390
L5
L805
R69
R64
L48
L85
L59
R12
R33
L880
L706
L15
R15
L80
R528
L81
L62
R95
R86
L40
L316
R87
R6
R46
L92
R28
R86
R9
R25
R75
L77
L5
R20
L89
L38
L83
R72
R610
L90
L2
R925
R57
L970
L50
R20
R19
R877
R11
R193
R80
R64
L9
L16
R6
R64
L89
L95
R495
R55
L713
L42
L31
R326
L37
L24
L82
R27
L63
R6
R21
R57
L34
L813
R28
L60
R65
L86
R96
R4
R684
L84
L72
L22
L6
L36
R336
R2
R199
L1
L23
L93
L44
L930
L70
R86
L526
R19
R4
L97
R74
R269
L79
R10
L4
L96
R839
R3
L10
R68
L94
R27
L78
L545
L98
R88
L286
L543
R329
L12
R81
L69
L47
L53
L56
L20
R56
L26
L169
R15
R53
L18
L35
R26
R274
R63
R37
R94
R405
L231
L51
R83
L97
L24
L29
L31
L38
L52
R71
R988
L67
L57
L91
L63
R90
R48
R52
R5
R95
L44
R2
R13
L20
L21
L48
R760
R65
R41
R996
R787
R82
L65
L232
R884
L88
L12
L921
R821
R758
R83
R259
R11
L11
L77
R21
L44
L37
R37
R28
R27
R26
L40
R59
R74
R32
R94
L491
L25
R99
L238
R60
L50
R45
L381
L54
R15
R20
R95
R305
R52
L24
L86
R46
L88
R46
R480
L26
L60
L91
L15
L73
R89
R770
R768
R68
R746
L2
L31
L153
L62
L54
L43
R58
R55
R98
R778
L246
R93
R307
L50
L83
R66
R14
R6
R797
R50
L76
L53
L83
R92
R20
L82
L73
R55
R75
L83
R872
R21
L85
R40
L40
L99
R74
R26
R86
L87
L81
R81
L666
L130
R83
L887
R299
R49
R57
R47
R51
R86
R11
L71
L57
R6
L60
L66
L50
R98
L28
L795
L29
R352
L62
R91
L76
L53
L93
L97
R90
R82
R18
L67
R86
L57
R638
L10
R749
L2
L57
L187
R7
R53
R2
L55
R835
L935
L2
L77
R5
R74
L94
R40
R54
R169
L60
L909
L61
L10
L29
L25
R25
L10
L12
R822
L24
L49
L82
L19
R34
L160
L62
L50
L88
R25
L25
L603
R45
L42
R9
R44
L53
R47
R55
L302
R23
R70
L40
L860
R75
R32
R67
R33
L331
R47
R55
L46
R275
R82
L82
L389
L266
L59
L188
L98
L11
R48
R85
L379
R18
R92
R85
L38
R95
L395
L82
R96
L14
L278
R78
L72
R367
R71
R60
R74
R75
R386
R68
L971
R8
R83
R51
L25
L86
L86
L99
L61
L43
R94
L882
L90
R76
R550
R398
R54
L1
L99
L90
R90
R7
R663
L94
L492
L76
L75
L639
R69
R58
L21
R19
L70
L49
L79
L21
R60
R38
L63
L18
L75
L42
L698
L877
L25
R38
R62
L996
R96
R33
L71
R38
L14
L86
L17
R15
R2
L51
L18
L76
L71
L88
L96
R96
R54
L64
L3
L683
L77
L78
R55
L29
R730
L7
R6
R63
R37
L864
L353
R6
L90
R80
R21
R45
L283
R38
L91
R51
L11
L65
R68
R15
R11
R22
R64
R46
R12
R58
L780
R27
R73
R90
L11
R356
L8
R23
R25
R25
R87
R91
R83
L77
L85
R565
L31
L34
R68
R33
L198
R49
R42
R265
L98
R74
L34
L19
L70
L11
L76
R24
L17
R772
L67
R64
L24
R724
L13
L74
L91
L16
R95
R1
L30
R78
R77
R53
L80
L23
R61
R41
L79
L62
R62
R18
R82
L21
L48
R69
R72
L72
L212
R68
L937
R99
R84
R98
L984
L16
L528
R65
L171
R43
R91
L96
L4
R70
R36
L70
R5
R59
L89
L11
L99
R12
R87
L27
L17
R99
R45
L19
R82
L63
L28
L30
R888
L20
L519
R81
L26
L837
L56
R29
L82
R76
R86
L231
L873
L82
L191
L59
L21
R90
L95
R514
L9
L12
L93
R63
R37
R3
R755
R59
R83
R19
L38
R74
L8
L47
R851
L44
R3
R86
L68
R41
L81
R92
L280
R88
L20
R683
R49
L94
L41
R337
R47
L16
R74
L82
L25
L75
R45
L70
L89
L237
L74
R37
R65
L56
R733
L79
R43
L45
L698
L50
L99
L19
R68
L64
L53
L56
R90
L717
R54
R46
R71
R829
L30
L70
R94
R80
L74
R4
L42
L38
L24
L58
L78
R36
R626
L61
R537
L20
L179
L63
L40
R37
L56
L20
R39
L76
R16
L23
R51
L68
L54
R45
R709
L387
L13
L866
R66
L665
L48
L87
L42
L558
L62
L24
R402
R72
L4
L884
L827
L73
R51
L51
L332
L37
L32
L78
L87
L734
L4
L55
L741
L53
L47
L11
R11
R178
L22
L56
R58
R269
R53
L80
L2
R83
R19
L970
R70
L92
R153
L51
L352
L419
R63
R44
R63
R76
L85
R68
L68
L18
L89
R67
R76
L136
L56
R56
L41
R241
L1
L52
R13
L60
R18
L26
R92
R185
L33
R854
L11
R25
L4
R99
R1
R309
R55
L64
L79
L21
R98
L726
L60
R88
R69
R332
R65
R23
L89
R65
L742
L84
R15
R502
R44
R65
R31
R34
R47
L816
L3
L243
R288
L14
L89
R32
L32
L644
R75
L31
R90
R12
R242
R62
L64
L69
L73
L874
R74
R46
L46
L57
L88
R70
R86
R89
R45
L343
L37
L65
L2
R697
L86
L294
L87
L13
R51
R34
L77
R89
L314
L37
R63
L268
L61
L22
R61
R982
L553
R805
L568
R5
R95
L57
L1
R31
R27
R34
R73
L82
L25
L73
L41
R14
L42
R17
L21
R642
L12
L884
R78
R922
R299
R1
R59
R18
L47
R70
L32
R113
R68
L15
R66
L59
L55
L486
L45
L55
L87
R64
L71
R91
L89
R92
R185
L23
R96
R42
R61
R39
L778
R464
L62
L24
R513
L599
L214
L85
L85
L39
R427
R85
L44
L611
R754
R19
R22
L752
R618
L9
R78
L51
R70
R38
L35
L98
L2
L182
R80
R302
R17
R83
R26
L359
L99
R32
L5
L49
L46
R120
L57
L250
L50
L58
R11
R49
R63
R72
L17
R17
R35
R566
R47
L84
R36
R91
R87
L78
L97
L862
L41
L1
L91
L8
R633
L51
R94
R24
L70
R27
L3
L35
L81
R13
R49
R25
R67
R8
L35
L19
R52
R702
R11
R492
R897
R11
R2
R49
L62
R64
R1
R38
R25
R4
L32
L60
R37
R18
L81
L14
L63
L76
L14
R859
R94
L28
R28
L98
L107
R69
R736
L994
R69
R25
L81
L10
R24
L750
R56
L99
L83
R76
R843
R63
L17
L18
L4
L85
L25
R10
R335
R74
R91
R729
R81
L6
R887
R9
L83
L46
L15
R48
L33
L308
R18
L437
R37
R19
R56
R5
R17
R59
L627
L50
L117
L643
R95
L63
L64
R96
R50
R328
R85
L78
R875
R27
R49
R241
L45
L96
R4
R96
L26
R26
R417
R83
L39
R43
L4
L69
L41
L63
R67
R74
R37
R95
R30
R53
L83
R33
L36
R144
R40
R519
L71
L41
R448
R64
R38
R262
L1
L99
R248
L48
L98
R68
R830
R93
R20
L13
R52
R48
R13
L51
L723
R142
R19
R370
L70
L957
R33
R35
L90
L21
R90
L90
R80
L90
R27
L1
L816
R49
L82
L27
R62
R30
R81
R87
L78
L22
L491
R86
R439
R276
R90
L48
L50
R798
R42
R346
L42
R34
L72
L8
L98
L24
R92
L70
R48
R41
L51
R62
L80
L685
R78
R35
L830
L218
R23
L991
R98
L130
L76
L81
L30
R87
R426
R874
L15
L85
R3
L236
R33
L69
L41
L17
L73
L336
L64
R16
L704
L312
R41
L24
R89
R89
R86
R62
L143
L8
L99
R715
R33
R59
R934
L35
R32
R69
R69
R62
R45
L76
R121
L27
L48
L22
R359
R17
R67
R52
L41
R91
R24
R96
L9
R79
R41
R36
R808
R261
R93
R74
R928
R46
R184
L88
R69
R889
R78
R11
L256
L44
L74
L15
L40
R840
R33
R67
R84
L48
L39
R484
R198
R21
R66
R61
L81
L42
R890
R406
R12
R89
L601
L29
L92
R401
R97
L38
R18
R81
R984
L47
R98
R4
L66
R89
R46
L46
L30
L84
L86
R67
L81
L86
L78
R78
L61
L30
R72
R22
R70
R27
R29
R271
R68
L68
R20
R80
R90
R5
R5
R36
R75
R10
L28
R99
R41
L33
L66
L334
R39
L39
L37
L13
R87
R963
R99
L10
R3
R8
L34
L66
R80
L93
R11
L98
L83
L19
L98
R61
R143
R79
L35
R952
R16
R84
R145
L66
R21
L874
L26
R39
L48
L46
R55
L10
R79
R31
L52
L348
R9
L916
L93
R51
L16
R65
R12
L16
R60
R44
R38
R96
R66
R3
L60
R78
L21
R32
R37
L72
L80
R1
L61
L414
L53
R879
R48
L60
R98
R45
L52
L60
L97
L39
R84
L45
R9
L6
R78
L32
L86
R71
L66
L69
R710
L49
L23
L54
L74
L36
L90
L174
L35
L34
R37
R48
R84
L46
L14
L27
R63
R738
L14
L968
R99
L60
L71
L93
L193
L14
R77
L703
R42
R84
R19
L83
L54
L298
L98
R46
R26
R42
L60
L56
L984
L24
L26
L50
L894
L6
L51
L49
L55
L45
R499
R40
R61
R43
L43
R788
R20
R72
R22
R91
L93
L70
R70
L83
R99
L16
L95
L34
L49
L739
L83
R420
L98
R813
R59
L95
R1
R503
L73
R28
R42
L19
L81
R36
L15
R50
R29
R87
L9
L51
L52
R14
L61
L1
R163
L62
R95
R77
L544
R44
R86
L397
L89
L624
L35
L459
L82
L81
L19
L43
L99
L58
R22
R21
L441
R98
L489
R89
R69
R52
R79
L82
R74
L69
L23
R85
L385
R26
L516
R90
L33
R81
R6
R13
R33
R28
L56
R27
R20
L39
R20
R54
L54
L57
L43
R40
L40
L79
L60
L61
R721
R87
L408
R21
R79
L79
R281
L40
L69
L10
L30
R503
L56
L54
R45
L91
R94
R93
R41
R42
L7
R645
L243
L404
R11
L67
R395
R43
L4
R61
R588
R8
L96
R970
R130
L932
R25
R9
L10
L992
L68
L54
L56
L322
L48
L52
L11
L26
R52
R85
R940
L36
R96
L37
L63
R90
L27
L24
R46
L30
R745
L432
L56
L55
R43
L88
R64
L510
R79
R58
R59
L11
L62
R63
L52
R46
R23
R39
L8
L67
R19
L87
R68
L12
L82
R63
L2
R27
L827
R7
L775
L32
L70
R70
L48
L129
R54
L77
R34
L34
L69
R568
L8
R38
R1
L30
R732
L14
L630
R12
L92
L8
R58
R92
R50
L36
L25
L39
R524
L24
R323
L87
R634
R93
R33
R89
L26
L59
L60
R60
R13
R64
R52
R59
R412
R103
R67
R10
L9
R544
R20
L35
R715
L21
R6
L54
R54
L28
R83
L55
L29
L902
L71
L73
L23
L82
R232
R30
R52
R66
R64
L79
R15
R1
L79
R512
R90
L24
R20
L20
R34
L34
L462
R74
L13
R64
L652
R59
L70
L22
L5
L773
R5
R842
L647
R69
R31
R33
L62
R49
L20
R45
L43
R378
L74
R79
L94
L91
L80
R3
R67
R87
R35
R99
L11
L992
L24
R105
R93
L475
R18
R39
L64
R89
R121
R19
L85
L16
L28
L10
R610
R80
R55
R73
R84
R1
L93
L64
R564
L783
R244
R13
L97
R28
R9
L14
L63
R89
L369
L26
R769
L584
L16
R69
R75
L44
L13
R378
R35
R134
R8
R58
L14
L25
L98
L151
L12
R52
L973
L464
R85
L259
L17
L24
L59
R69
R353
R37
L76
R76
L525
R10
L48
L9
R72
L4
L1
L20
L492
R119
L30
R515
R39
R87
R87
L446
R36
R77
R33
R95
L64
L31
L13
L23
R7
R29
R89
L76
L13
L87
R94
R93
L77
L23
R37
R94
R32
R20
R44
L93
R66
L89
R5
L16
L49
L93
L65
L47
L46
R75
R25
L25
L31
L74
L514
L56
R885
L85
L94
R65
R29
L92
R9
L194
L67
R44
R22
R664
R14
R47
R53
L39
L26
L37
R2
L56
L244
L43
L420
L37
L90
L99
L11
R37
L70
R33
L53
R53
L95
R97
R98
R16
R89
L36
L69
L54
R40
R14
R34
R56
L44
L18
R38
L66
R35
R65
L77
R77
L20
R34
R86
R12
R58
R50
L58
R91
R47
R94
L1
L93
R66
R99
L79
R15
L41
L60
L32
R32
R63
L33
L70
R81
R39
L3
R38
L7
L14
L46
R24
R11
R9
R48
L35
L15
R3
L20
L6
R41
L38
L40
R35
L39
L49
R48
R4
R4
L4
L49
L47
L32
R29
L30
L48
L33
R19
L25
L32
L49
R32
R15
R25
R23
R2
R30
R9
L38
R27
R6
R17
L19
R42
R48
R39"""

# %%
l = test.split("\n")
l = actual.split("\n")

l
# Out:
# ['L49',
#  'L24',
#  'R48',
#  'L16',
#  'L2',
#  'R8',
#  'R48',
#  'L27',
#  'L2',
#  'L47',
#  'R48',
#  'L41',
#  'L3',
#  'R39',
#  'R45',
#  'R43',
#  'L4',
#  'R47',
#  'R38',
#  'R17',
#  'R45',
#  'L4',
#  'L25',
#  'L30',
#  'R7',
#  'L44',
#  'R15',
#  'R42',
#  'L40',
#  'R11',
#  'R35',
#  'R36',
#  'R4',
#  'L24',
#  'R40',
#  'L11',
#  'R9',
#  'R48',
#  'R3',
#  'R37',
#  'L30',
#  'L2',
#  'R45',
#  'R24',
#  'L26',
#  'L40',
#  'L11',
#  'R46',
#  'L27',
#  'R51',
#  'L30',
#  'L90',
#  'R20',
#  'R4',
#  'R85',
#  'L96',
#  'R7',
#  'R1',
#  'L53',
#  'R82',
#  'R70',
#  'L61',
#  'R70',
#  'L60',
#  'L54',
#  'L81',
#  'R86',
#  'R82',
#  'R18',
#  'R54',
#  'L26',
#  'R58',
#  'L69',
#  'L17',
#  'L99',
#  'L58',
#  'R10',
#  'R83',
#  'R64',
#  'R79',
#  'L5',
#  'L27',
#  'L34',
#  'R87',
#  'L12',
#  'L89',
#  'R19',
#  'R70',
#  'L40',
#  'R42',
#  'R10',
#  'R37',
#  'R79',
#  'R74',
#  'L53',
#  'L74',
#  'R27',
#  'L90',
#  'R69',
#  'L69',
#  'R42',
# ...

# %% [markdown]
# # PART 1

# %%
l_out = [50]
for n in l:
    match n[0]:
        case "L":
            l_out.append((l_out[-1] - int(n[1:])) % 100)
        case "R":
            l_out.append((l_out[-1] + int(n[1:])) % 100)


l_out

sum([1 if n == 0 else 0 for n in l_out])
# Out:
# 984

# %% [markdown]
# # PART 2

# %%
# initialise list of ending positions
l_out = [50]

# initialise variable for counting total clicks
clicks = 0

# iterate through list of instructions
for n in l:
    new_clicks = 0

    # find out if we're going left or right, and calculate result
    match n[0]:
        case "L":
            # special case where we move left after landing at 0, we subtract 1 because an extra 1 will be counted by the logic below...
            if l_out[-1] == 0:
                new_clicks = -1

            res = l_out[-1] - int(n[1:])
        case "R":
            res = l_out[-1] + int(n[1:])

    # next position is result mod 100
    l_out.append(res % 100)

    # calculate number of new clicks based on final position
    if res <= 0:
        new_clicks += abs((res - 1) // 100)
    else:
        new_clicks += abs(res // 100)
    clicks += new_clicks


print(f"{clicks = }")
print(f"stops at 0: {sum([1 if n == 0 else 0 for n in l_out])}")
# Out:
# clicks = 5657
# stops at 0: 984

# %%
abs(-100 // 100)
# Out:
# 1
